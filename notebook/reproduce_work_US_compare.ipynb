# %%
import pandas as pd
import glob
import os
import json
import numpy as np
from  cycler import cycler
import fastplot
from collections import Counter, defaultdict
from statistics import mode
import statsmodels.stats.proportion
import re

state_list = ['us-ohio', 'us-california', 'us-virginia']
country_list_USA = ['USA']
COUNTRY_TRAD={"us-ohio":"Ohio", "us-california":"California", "us-virginia": "Virginia"}

CYCLER_LINESPOINTS=(cycler('color', ['r', 'b', 'g', 'purple', 'c']) +
                    cycler('linestyle', ['-', '--', '-.', ':', (0, (3, 1, 1, 1)) ]) +
                    cycler('marker', ['o', 's', 'v', 'd', '^' ]))

CYCLER_LINES=(cycler('color', ['r', 'b', 'g', 'purple', 'c']) +
                    cycler('linestyle', ['-', '--', '-.', ':', (0, (3, 1, 1, 1)) ]))

PLOT_ARGS = {"style":"latex", "grid":True, "figsize":(4.25,2.5), "rcParams":{'text.latex.preamble': '\\usepackage{libertine}\n\\usepackage{setspace}'}, "legend_args":{"columnspacing":1, "handlelength":1.5}}
PLOT_ARGS_LARGE = {"style":"latex", "grid":True, "figsize":(9,2.75), "rcParams":{'text.latex.preamble': '\\usepackage{libertine}\n\\usepackage{setspace}'}, "legend_args":{"columnspacing":1, "handlelength":1.5}}

BEFORE_STR = "\\emph{Before-Accept}"
AFTER_STR = "\\emph{After-Accept}"
ADDITIONAL_STR = "\\emph{Additional-Visits}"

TRANSLATE_CATEGORIES = {"Computers Electronics and Technology": "Computers and Technology",
                        "Business and Consumer Services": "Business and Services",
                        "Heavy Industry and Engineering": "Industry and Engineering"}

# %matplotlib inline

# %%
trackers = set( open("trackers-list.txt", "r").read().splitlines() )

# %%
dfs = []
for state in state_list:
    print(state)
    temp_df = pd.read_csv(f"../data/{state}_output.csv")
    temp_df[state] = True
    dfs.append(temp_df)
    
df = pd.concat(dfs, ignore_index=True)
print(df)
# Out:
# us-ohio
# us-california
# us-virginia
#                           url  \
# 0         http://character.ai
# 1      http://skinnytaste.com
# 2       http://eatingwell.com
# 3              http://loc.gov
# 4          http://generac.com
# ...                       ...
# 6374     http://mlsmatrix.com
# 6375  http://litter-robot.com
# 6376        http://redfin.com
# 6377              http://t.me
# 6378    http://wikisource.org
#
#                                            landing_page  has_found_banner  \
# 0                                 https://character.ai/             False
# 1                          https://www.skinnytaste.com/             False
# 2                           https://www.eatingwell.com/             False
# 3                                      https://loc.gov/             False
# 4                                  https://generac.com/             False
# ...                                                 ...               ...
# 6374                              http://mlsmatrix.com/             False
# 6375                      https://www.litter-robot.com/             False
# 6376                    https://ratelimited.redfin.com/             False
# 6377                              https://telegram.org/             False
# 6378  https://wikisource.org/wiki/Main_Page/%E0%B7%8...              True
#
#                                            cookie_first  \
# 0     [{"domain": "www.google.com", "expires": 17249...
# 1     [{"domain": ".3lift.com", "expires": 171719202...
# 2     [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3     [{"domain": ".demdex.net", "expires": 17249748...
# 4     [{"domain": ".generac.com", "expires": 1740897...
# ...                                                 ...
# 6374                                                 []
# 6375  [{"domain": ".liadm.com", "expires": 174462602...
# 6376                                                 []
# 6377  [{"domain": "t.me", "expires": 1710152757.5461...
# 6378  [{"domain": "wikisource.org", "expires": 17127...
#
#                                            cookie_click  \
# 0     [{"domain": "www.google.com", "expires": 17249...
# 1     [{"domain": ".3lift.com", "expires": 171719202...
# 2     [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3     [{"domain": ".demdex.net", "expires": 17249748...
# 4     [{"domain": ".generac.com", "expires": 1740897...
# ...                                                 ...
# 6374  [{"domain": ".valiantys.net", "expires": 17415...
# 6375  [{"domain": ".liadm.com", "expires": 174462602...
# 6376                                                 []
# 6377  [{"domain": "t.me", "expires": 1710152757.5461...
# 6378  [{"domain": "wikisource.org", "expires": 17127...
#
#                                         cookie_internal  \
# 0     [{"domain": "www.google.com", "expires": 17249...
# 1     [{"domain": ".3lift.com", "expires": 171719202...
# 2     [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3     [{"domain": ".demdex.net", "expires": 17249748...
# 4     [{"domain": ".generac.com", "expires": 1740897...
# ...                                                 ...
# 6374  [{"domain": ".valiantys.net", "expires": 17415...
# 6375  [{"domain": ".liadm.com", "expires": 174462632...
# 6376                                                 []
# 6377  [{"domain": "t.me", "expires": 1710152757.5461...
# 6378  [{"domain": "wikisource.org", "expires": 17127...
#
#                                           domains_first  \
# 0     ["wa.onelink.me", "static.cloudflareinsights.c...
# 1     ["www.skinnytaste.com", "c2shb.ssp.yahoo.com",...
# 2     ["securepubads.g.doubleclick.net", "proc.ad.cp...
# 3     ["unitedstateslibraryofcongress.demdex.net", "...
# 4     ["generac.com", "fonts.googleapis.com", "tags....
# ...                                                 ...
# 6374                                  ["mlsmatrix.com"]
# 6375  ["match.360yield.com", "cdn.attn.tv", "ups.ana...
# 6376                         ["ratelimited.redfin.com"]
# 6377                                   ["telegram.org"]
# 6378  ["upload.wikimedia.org", "meta.wikimedia.org",...
#
#                                           domains_click us-ohio us-california  \
# 0     ["static.cloudflareinsights.com", "events.char...    True           NaN
# 1     ["www.skinnytaste.com", "c2shb.ssp.yahoo.com",...    True           NaN
# 2     ["crb.kargo.com", "r.3gl.net", "securepubads.g...    True           NaN
# 3     ["smon.loc.gov", "loc.gov", "assets.adobedtm.c...    True           NaN
# 4     ["generac.com", "fonts.googleapis.com", "insig...    True           NaN
# ...                                                 ...     ...           ...
# 6374  ["fonts.gstatic.com", "fonts.googleapis.com", ...     NaN           NaN
# 6375  ["acdn.adnxs.com", "match.360yield.com", "cdn....     NaN           NaN
# 6376                         ["ratelimited.redfin.com"]     NaN           NaN
# 6377                                   ["telegram.org"]     NaN           NaN
# 6378  ["upload.wikimedia.org", "meta.wikimedia.org",...     NaN           NaN
#
#      us-virginia
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6374        True
# 6375        True
# 6376        True
# 6377        True
# 6378        True
#
# [6379 rows x 11 columns]

# %%
bad_domains=set("co.uk co.jp com.hk co.hu co.il com.au co.ve .co.in com.ec com.pk co.th co.nz com.br com.sg com.sa \
com.do co.za com.mx com.ly com.ua com.eg com.pe com.tr co.kr com.ng com.pe com.pk co.th \
com.au com.ph com.my com.tw com.ec com.kw co.in co.id com.com com.vn com.bd com.ar \
com.co com.vn org.uk net.gr".split())

def getGood2LD(fqdn):
    if fqdn[-1] == ".":
        fqdn = fqdn[:-1]    
    names = fqdn.split(".")
    if ".".join(names[-2:]) in bad_domains:
        return get3LD(fqdn)
    tln_array = names[-2:]
    tln = ""
    for s in tln_array:
        tln = tln + "." + s
    return tln[1:]

def get3LD(fqdn):
    if fqdn[-1] == ".":
        fqdn = fqdn[:-1]
    names = fqdn.split(".")
    tln_array = names[-3:]
    tln = ""
    for s in tln_array:
        tln = tln + "." + s
    return tln[1:]

# %%
# Initialize a list to store indices of rows to be deleted
rows_to_delete = []

for index, row in df.iterrows():
    # Check if the specified columns are empty for the row
    if row['cookie_first'] == "[]" and row['cookie_click'] == "[]" and row['cookie_internal'] == "[]":
        rows_to_delete.append(index)

# Drop the identified rows
df.drop(rows_to_delete, inplace=True)
df.reset_index(drop=True, inplace=True)

print(f"Number of rows deleted: {len(rows_to_delete)}")
# Out:
# Number of rows deleted: 742

# %%
df["sld"] = df["url"].apply(lambda u: getGood2LD(u.split("/")[2] ).strip() ) 
df["tld"] = df["url"].apply(lambda u: get3LD(u.split("/")[2] ).strip()  )

# %%
print(df)
# Out:
#                           url  \
# 0         http://character.ai
# 1      http://skinnytaste.com
# 2       http://eatingwell.com
# 3              http://loc.gov
# 4          http://generac.com
# ...                       ...
# 5632       http://pushpay.com
# 5633     http://mlsmatrix.com
# 5634  http://litter-robot.com
# 5635              http://t.me
# 5636    http://wikisource.org
#
#                                            landing_page  has_found_banner  \
# 0                                 https://character.ai/             False
# 1                          https://www.skinnytaste.com/             False
# 2                           https://www.eatingwell.com/             False
# 3                                      https://loc.gov/             False
# 4                                  https://generac.com/             False
# ...                                                 ...               ...
# 5632                               https://pushpay.com/             False
# 5633                              http://mlsmatrix.com/             False
# 5634                      https://www.litter-robot.com/             False
# 5635                              https://telegram.org/             False
# 5636  https://wikisource.org/wiki/Main_Page/%E0%B7%8...              True
#
#                                            cookie_first  \
# 0     [{"domain": "www.google.com", "expires": 17249...
# 1     [{"domain": ".3lift.com", "expires": 171719202...
# 2     [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3     [{"domain": ".demdex.net", "expires": 17249748...
# 4     [{"domain": ".generac.com", "expires": 1740897...
# ...                                                 ...
# 5632  [{"domain": ".taboola.com", "expires": -1, "si...
# 5633                                                 []
# 5634  [{"domain": ".liadm.com", "expires": 174462602...
# 5635  [{"domain": "t.me", "expires": 1710152757.5461...
# 5636  [{"domain": "wikisource.org", "expires": 17127...
#
#                                            cookie_click  \
# 0     [{"domain": "www.google.com", "expires": 17249...
# 1     [{"domain": ".3lift.com", "expires": 171719202...
# 2     [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3     [{"domain": ".demdex.net", "expires": 17249748...
# 4     [{"domain": ".generac.com", "expires": 1740897...
# ...                                                 ...
# 5632  [{"domain": ".taboola.com", "expires": -1, "si...
# 5633  [{"domain": ".valiantys.net", "expires": 17415...
# 5634  [{"domain": ".liadm.com", "expires": 174462602...
# 5635  [{"domain": "t.me", "expires": 1710152757.5461...
# 5636  [{"domain": "wikisource.org", "expires": 17127...
#
#                                         cookie_internal  \
# 0     [{"domain": "www.google.com", "expires": 17249...
# 1     [{"domain": ".3lift.com", "expires": 171719202...
# 2     [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3     [{"domain": ".demdex.net", "expires": 17249748...
# 4     [{"domain": ".generac.com", "expires": 1740897...
# ...                                                 ...
# 5632  [{"domain": ".taboola.com", "expires": -1, "si...
# 5633  [{"domain": ".valiantys.net", "expires": 17415...
# 5634  [{"domain": ".liadm.com", "expires": 174462632...
# 5635  [{"domain": "t.me", "expires": 1710152757.5461...
# 5636  [{"domain": "wikisource.org", "expires": 17127...
#
#                                           domains_first  \
# 0     ["wa.onelink.me", "static.cloudflareinsights.c...
# 1     ["www.skinnytaste.com", "c2shb.ssp.yahoo.com",...
# 2     ["securepubads.g.doubleclick.net", "proc.ad.cp...
# 3     ["unitedstateslibraryofcongress.demdex.net", "...
# 4     ["generac.com", "fonts.googleapis.com", "tags....
# ...                                                 ...
# 5632  ["d3ltkmc4jesp6t.cloudfront.net", "get.exitint...
# 5633                                  ["mlsmatrix.com"]
# 5634  ["match.360yield.com", "cdn.attn.tv", "ups.ana...
# 5635                                   ["telegram.org"]
# 5636  ["upload.wikimedia.org", "meta.wikimedia.org",...
#
#                                           domains_click us-ohio us-california  \
# 0     ["static.cloudflareinsights.com", "events.char...    True           NaN
# 1     ["www.skinnytaste.com", "c2shb.ssp.yahoo.com",...    True           NaN
# 2     ["crb.kargo.com", "r.3gl.net", "securepubads.g...    True           NaN
# 3     ["smon.loc.gov", "loc.gov", "assets.adobedtm.c...    True           NaN
# 4     ["generac.com", "fonts.googleapis.com", "insig...    True           NaN
# ...                                                 ...     ...           ...
# 5632  ["get.exitintel.com", "dev.visualwebsiteoptimi...     NaN           NaN
# 5633  ["fonts.gstatic.com", "fonts.googleapis.com", ...     NaN           NaN
# 5634  ["acdn.adnxs.com", "match.360yield.com", "cdn....     NaN           NaN
# 5635                                   ["telegram.org"]     NaN           NaN
# 5636  ["upload.wikimedia.org", "meta.wikimedia.org",...     NaN           NaN
#
#      us-virginia               sld               tld
# 0            NaN      character.ai      character.ai
# 1            NaN   skinnytaste.com   skinnytaste.com
# 2            NaN    eatingwell.com    eatingwell.com
# 3            NaN           loc.gov           loc.gov
# 4            NaN       generac.com       generac.com
# ...          ...               ...               ...
# 5632        True       pushpay.com       pushpay.com
# 5633        True     mlsmatrix.com     mlsmatrix.com
# 5634        True  litter-robot.com  litter-robot.com
# 5635        True              t.me              t.me
# 5636        True    wikisource.org    wikisource.org
#
# [5637 rows x 13 columns]

# %%
similarweb_csv = pd.read_csv("similarweb/together.csv")

# %%
# adding categories to the dataframe
similarweb_csv["category"] = similarweb_csv["category"].apply(lambda s: TRANSLATE_CATEGORIES[s] if s in TRANSLATE_CATEGORIES else s)
categories = defaultdict(set)

for row in similarweb_csv.itertuples():
    if row.category != "ALL" and row.country in ["USA"] :
        categories[row.category].add(row.website)
        
for category in categories:
    df[category] = (df.sld.isin(categories[category])) | (df.tld.isin(categories[category]))

# %%
print(df)
# Out:
#                           url  \
# 0         http://character.ai
# 1      http://skinnytaste.com
# 2       http://eatingwell.com
# 3              http://loc.gov
# 4          http://generac.com
# ...                       ...
# 5632       http://pushpay.com
# 5633     http://mlsmatrix.com
# 5634  http://litter-robot.com
# 5635              http://t.me
# 5636    http://wikisource.org
#
#                                            landing_page  has_found_banner  \
# 0                                 https://character.ai/             False
# 1                          https://www.skinnytaste.com/             False
# 2                           https://www.eatingwell.com/             False
# 3                                      https://loc.gov/             False
# 4                                  https://generac.com/             False
# ...                                                 ...               ...
# 5632                               https://pushpay.com/             False
# 5633                              http://mlsmatrix.com/             False
# 5634                      https://www.litter-robot.com/             False
# 5635                              https://telegram.org/             False
# 5636  https://wikisource.org/wiki/Main_Page/%E0%B7%8...              True
#
#                                            cookie_first  \
# 0     [{"domain": "www.google.com", "expires": 17249...
# 1     [{"domain": ".3lift.com", "expires": 171719202...
# 2     [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3     [{"domain": ".demdex.net", "expires": 17249748...
# 4     [{"domain": ".generac.com", "expires": 1740897...
# ...                                                 ...
# 5632  [{"domain": ".taboola.com", "expires": -1, "si...
# 5633                                                 []
# 5634  [{"domain": ".liadm.com", "expires": 174462602...
# 5635  [{"domain": "t.me", "expires": 1710152757.5461...
# 5636  [{"domain": "wikisource.org", "expires": 17127...
#
#                                            cookie_click  \
# 0     [{"domain": "www.google.com", "expires": 17249...
# 1     [{"domain": ".3lift.com", "expires": 171719202...
# 2     [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3     [{"domain": ".demdex.net", "expires": 17249748...
# 4     [{"domain": ".generac.com", "expires": 1740897...
# ...                                                 ...
# 5632  [{"domain": ".taboola.com", "expires": -1, "si...
# 5633  [{"domain": ".valiantys.net", "expires": 17415...
# 5634  [{"domain": ".liadm.com", "expires": 174462602...
# 5635  [{"domain": "t.me", "expires": 1710152757.5461...
# 5636  [{"domain": "wikisource.org", "expires": 17127...
#
#                                         cookie_internal  \
# 0     [{"domain": "www.google.com", "expires": 17249...
# 1     [{"domain": ".3lift.com", "expires": 171719202...
# 2     [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3     [{"domain": ".demdex.net", "expires": 17249748...
# 4     [{"domain": ".generac.com", "expires": 1740897...
# ...                                                 ...
# 5632  [{"domain": ".taboola.com", "expires": -1, "si...
# 5633  [{"domain": ".valiantys.net", "expires": 17415...
# 5634  [{"domain": ".liadm.com", "expires": 174462632...
# 5635  [{"domain": "t.me", "expires": 1710152757.5461...
# 5636  [{"domain": "wikisource.org", "expires": 17127...
#
#                                           domains_first  \
# 0     ["wa.onelink.me", "static.cloudflareinsights.c...
# 1     ["www.skinnytaste.com", "c2shb.ssp.yahoo.com",...
# 2     ["securepubads.g.doubleclick.net", "proc.ad.cp...
# 3     ["unitedstateslibraryofcongress.demdex.net", "...
# 4     ["generac.com", "fonts.googleapis.com", "tags....
# ...                                                 ...
# 5632  ["d3ltkmc4jesp6t.cloudfront.net", "get.exitint...
# 5633                                  ["mlsmatrix.com"]
# 5634  ["match.360yield.com", "cdn.attn.tv", "ups.ana...
# 5635                                   ["telegram.org"]
# 5636  ["upload.wikimedia.org", "meta.wikimedia.org",...
#
#                                           domains_click us-ohio us-california  \
# 0     ["static.cloudflareinsights.com", "events.char...    True           NaN
# 1     ["www.skinnytaste.com", "c2shb.ssp.yahoo.com",...    True           NaN
# 2     ["crb.kargo.com", "r.3gl.net", "securepubads.g...    True           NaN
# 3     ["smon.loc.gov", "loc.gov", "assets.adobedtm.c...    True           NaN
# 4     ["generac.com", "fonts.googleapis.com", "insig...    True           NaN
# ...                                                 ...     ...           ...
# 5632  ["get.exitintel.com", "dev.visualwebsiteoptimi...     NaN           NaN
# 5633  ["fonts.gstatic.com", "fonts.googleapis.com", ...     NaN           NaN
# 5634  ["acdn.adnxs.com", "match.360yield.com", "cdn....     NaN           NaN
# 5635                                   ["telegram.org"]     NaN           NaN
# 5636  ["upload.wikimedia.org", "meta.wikimedia.org",...     NaN           NaN
#
#       ... Jobs_and_Career Law_and_Government News_and_Media  Pets_and_Animals  \
# 0     ...           False              False          False             False
# 1     ...           False              False          False             False
# 2     ...           False              False          False             False
# 3     ...           False               True          False             False
# 4     ...           False              False          False             False
# ...   ...             ...                ...            ...               ...
# 5632  ...           False              False          False             False
# 5633  ...           False              False          False             False
# 5634  ...           False              False          False              True
# 5635  ...           False              False          False             False
# 5636  ...           False              False          False             False
#
#       Reference_Materials  Science_and_Education  Sports  Travel_and_Tourism  \
# 0                   False                  False   False               False
# 1                   False                  False   False               False
# 2                   False                  False   False               False
# 3                   False                  False   False               False
# 4                   False                  False   False               False
# ...                   ...                    ...     ...                 ...
# 5632                False                  False   False               False
# 5633                False                  False   False               False
# 5634                False                  False   False               False
# 5635                False                  False   False               False
# 5636                 True                  False   False               False
#
#       Vehicles  Lifestyle
# 0        False      False
# 1        False      False
# 2        False      False
# 3        False      False
# 4        False      False
# ...        ...        ...
# 5632     False      False
# 5633     False      False
# 5634     False      False
# 5635     False      False
# 5636     False      False
#
# [5637 rows x 37 columns]

# %%
# getting the trackers for before, after and internal banner.
# Note that only checking the tracker that is in the tracker list and not expried
def get_trackers(s):
    d = json.loads(s)
    this_trackers = set()
    for c in d:
        if (c["domain"] in trackers or getGood2LD(c["domain"]) in trackers or get3LD(c["domain"]) in trackers) and c["expires"] > 0:
            this_trackers.add(getGood2LD(c["domain"]))
    return list(this_trackers)

df["trackers_first"] = df["cookie_first"].apply(lambda x: set(get_trackers(x)))
df["trackers_click"] = df["cookie_click"].apply(lambda x: set(get_trackers(x)))
df["trackers_internal"] = df["cookie_internal"].apply(lambda x: set(get_trackers(x)))

df['tp_first'] = df['domains_first'].apply(lambda x: set([getGood2LD(d) for d in json.loads(x) if d != ""]))
df['tp_click'] = df['domains_click'].apply(lambda x: set([getGood2LD(d) for d in json.loads(x) if d != ""]))

# %%
print(df.iloc[0])
# Out:
# url                                                                   http://character.ai
# landing_page                                                        https://character.ai/
# has_found_banner                                                                    False
# cookie_first                            [{"domain": "www.google.com", "expires": 17249...
# cookie_click                            [{"domain": "www.google.com", "expires": 17249...
# cookie_internal                         [{"domain": "www.google.com", "expires": 17249...
# domains_first                           ["wa.onelink.me", "static.cloudflareinsights.c...
# domains_click                           ["static.cloudflareinsights.com", "events.char...
# us-ohio                                                                              True
# us-california                                                                         NaN
# us-virginia                                                                           NaN
# sld                                                                          character.ai
# tld                                                                          character.ai
# Adult                                                                               False
# Arts_and_Entertainment                                                              False
# Business_and_Consumer_Services                                                      False
# Community_and_Society                                                               False
# Computers_Electronics_and_Technology                                                 True
# E-commerce_and_Shopping                                                             False
# Finance                                                                             False
# Food_and_Drink                                                                      False
# Gambling                                                                            False
# Games                                                                               False
# Health                                                                              False
# Heavy_Industry_and_Engineering                                                      False
# Hobbies_and_Leisure                                                                 False
# Home_and_Garden                                                                     False
# Jobs_and_Career                                                                     False
# Law_and_Government                                                                  False
# News_and_Media                                                                      False
# Pets_and_Animals                                                                    False
# Reference_Materials                                                                 False
# Science_and_Education                                                               False
# Sports                                                                              False
# Travel_and_Tourism                                                                  False
# Vehicles                                                                            False
# Lifestyle                                                                           False
# trackers_first                                                {google.com, appsflyer.com}
# trackers_click                                                {google.com, appsflyer.com}
# trackers_internal                                             {google.com, appsflyer.com}
# tp_first                                {cloudflareinsights.com, appsflyer.com, google...
# tp_click                                {cloudflareinsights.com, appsflyer.com, google...
# Name: 0, dtype: object

# %%
PLOT_ARGS_SMALL = {"style":"latex", "grid":True, "figsize":(2,2.25), "rcParams":{'text.latex.preamble': r'\usepackage{libertine}'}, "legend_args":{"columnspacing":1, "handlelength":1.5}}

W=100
for c in state_list:

    plot_data = df [ df[[c]].any(axis=1) ].copy()
    missing = 0#10542 - len(plot_data.index)
    plot_data["trackers_first_nb"] = plot_data["trackers_first"].apply(len)
    plot_data["trackers_click_nb"] = plot_data["trackers_click"].apply(len)
    plot_data = plot_data[["trackers_first_nb", "trackers_click_nb"]]

    # plot_data = plot_data.append( [{"trackers_first_nb":0, "trackers_click_nb":0}]*missing ).sample(frac=1)
    plot_data = plot_data._append( [{"trackers_first_nb":0, "trackers_click_nb":0}]*missing ).sample(frac=1)

    plot_data= plot_data.sort_values(by="trackers_first_nb", ascending=False).reset_index()
    plot_list = [(BEFORE_STR,   (np.arange(len(plot_data["trackers_first_nb"].values ) ) +1 ,   plot_data["trackers_first_nb"].values  ) ),
                 (AFTER_STR, (np.arange(len(plot_data["trackers_click_nb"].values) ) +1 , plot_data["trackers_click_nb"].values ) ),
                ]

    avg = (np.arange(len(plot_data["trackers_click_nb"].values) ) +1 , plot_data["trackers_click_nb"].rolling(W).mean().values )
        
    CYCLER_LINESANDPOINTS=(cycler('color', ['r', 'b', 'b', 'b', 'c']) +
                        cycler('linestyle', ['-', '', '-.', '-', (0, (3, 1, 1, 1)) ]) +
                        cycler('marker', ['', 's', '', '', '^' ]))

    has_legend = c == "fr"
    ylabel = 'Tracker Number' if has_legend else None
    yticks = ([0,20,40,60,80],None) if has_legend else ([0,20,40,60,80],["","","","",""])
    #xlabel = "{}\\\\Websites".format(COUNTRY_TRAD[c]) if c == "it" else "{}".format(COUNTRY_TRAD[c])
    xlabel = "{}".format(COUNTRY_TRAD[c])
    
    plot = fastplot.plot( plot_list ,None, 
                   mode='line_multi', ylabel = ylabel,
                   legend = has_legend, legend_loc='upper right', legend_ncol=1, legend_fontsize=12, legend_alpha=0.5,
                     xlabel = "Websites", linewidth=2, fontsize=12,
                   xlim = (-100, 2500), cycler = CYCLER_LINESANDPOINTS, plot_args = {"markersize": 1},
                         xticks = ([0,1000,2000],None), yticks = yticks,
                   ylim = (-5,80), **PLOT_ARGS_SMALL)

    if has_legend:
        # plot.gca().get_legend().legendHandles[1]._legmarker.set_markersize(5)
        plot.gca().get_legend().legend_handles[1].set_markersize(5)
    plot.plot(plot_list[0][1][0], plot_list[0][1][1], "-", color="red", marker=None, markersize=0)
    plot.title(xlabel)
    
    plot.plot(avg[0], avg[1])
    
    plot.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9) 
    plot.savefig("plots/cookieaccept_overall_tracker_nb_{}.pdf".format(c), bbox_inches = "tight")
    
    plot.show()

# %%
plot_data = []

for state in state_list:
    this_grouped = df[df[state] == True]
    print(this_grouped)
    tot = len(this_grouped.index)
    tracker_first = len(this_grouped[this_grouped["trackers_first"].apply(lambda s: len(s) > 0 ) ].index)
    tracker_click = len(this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) > 0 ) ].index)
    tracker_internal = len(this_grouped[this_grouped["trackers_internal"].apply(lambda s: len(s) > 0 ) ].index)
    plot_data.append({"state": COUNTRY_TRAD[state],
                      BEFORE_STR: tracker_first/tot*100,
                      AFTER_STR: tracker_click/tot*100,
                      ADDITIONAL_STR: tracker_internal/tot*100,
                     })
    
plot_df = pd.DataFrame(plot_data)
plot_df = plot_df.sort_values(by="state")
plot_df.index = plot_df["state"]
del plot_df["state"]

THIS_PLOT_ARGS = PLOT_ARGS.copy()
THIS_PLOT_ARGS["figsize"] = (4.25,2.25)
    
plot = fastplot.plot( plot_df ,None, 
               mode='bars_multi', ylabel = 'Websites With Trackers [\\%]',
               legend = True, legend_loc='upper left', legend_ncol=3, legend_fontsize="small",
               grid_axis="y",
               ylim = (0,100), **THIS_PLOT_ARGS)


for p in plot.gca().patches[:len(plot_df)] + [plot.gca().get_legend().get_patches()[0]]:
    p.set_hatch("\\\\\\\\\\")
    p.set_edgecolor ("red")
    p.set_facecolor ("white")
for p in plot.gca().patches[len(plot_df):len(plot_df)*2]+ [plot.gca().get_legend().get_patches()[1]]:
    p.set_hatch("/////")
    p.set_edgecolor ("blue")
    p.set_facecolor ("white")
    
for p in plot.gca().patches[2*len(plot_df):] + [plot.gca().get_legend().get_patches()[2]]:
    p.set_hatch("----")
    p.set_edgecolor ("green")
    p.set_facecolor ("white")

#plot.gca().patches[5].set_hatch("XXXX")
#plot.gca().patches[11].set_hatch("++++")
#plot.gca().patches[17].set_hatch("....")

for i, state in enumerate(state_list):
    this_grouped = df[df[state] == True]
    n = round(len(this_grouped[this_grouped["has_found_banner"]].index)/len(this_grouped.index)*100,1)
    plot.text(i, 105, "{}\\%".format(n), ha="center", bbox = dict(boxstyle='square,pad=0', color="white"))
    
plot.text(2.5, 115, "Consent Banner Found and Accepted", ha="center", bbox = dict(boxstyle='square,pad=0', facecolor='white', color="white"))

plot.subplots_adjust(left=0.125, bottom=0.1, right=0.95, top=0.85) 

# err = plot_df.applymap(lambda v: [ e*100 for e in statsmodels.stats.proportion.proportion_confint(v*2500/100,2500,0.05) ]  )
err = plot_df.map(lambda v: [ e*100 for e in statsmodels.stats.proportion.proportion_confint(v*2500/100,2500,0.05) ]  )
for i, tup in enumerate(err.itertuples()):
    plot.gca().plot( (i-0.2,i-0.2), (tup[1]), linestyle="-", color="black"  )
    plot.gca().plot( (i,i), (tup[2]), linestyle="-", color="black" )
    plot.gca().plot( (i+0.2,i+0.2), (tup[3]), linestyle="-", color="black" )
    
plot.savefig("plots/cookieaccept_websites_with_trackers.pdf", bbox_inches = "tight")
plot.show()
# Out:
#                           url  \
# 0         http://character.ai
# 1      http://skinnytaste.com
# 2       http://eatingwell.com
# 3              http://loc.gov
# 4          http://generac.com
# ...                       ...
# 1882       http://pushpay.com
# 1883          http://ford.com
# 1884  http://litter-robot.com
# 1885              http://t.me
# 1886    http://wikisource.org
#
#                                            landing_page  has_found_banner  \
# 0                                 https://character.ai/             False
# 1                          https://www.skinnytaste.com/             False
# 2                           https://www.eatingwell.com/             False
# 3                                      https://loc.gov/             False
# 4                                  https://generac.com/             False
# ...                                                 ...               ...
# 1882                               https://pushpay.com/             False
# 1883                              https://www.ford.com/             False
# 1884                      https://www.litter-robot.com/             False
# 1885                              https://telegram.org/             False
# 1886  https://wikisource.org/wiki/Main_Page/%E0%B7%8...              True
#
#                                            cookie_first  \
# 0     [{"domain": "www.google.com", "expires": 17249...
# 1     [{"domain": ".3lift.com", "expires": 171719202...
# 2     [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3     [{"domain": ".demdex.net", "expires": 17249748...
# 4     [{"domain": ".generac.com", "expires": 1740897...
# ...                                                 ...
# 1882  [{"domain": ".taboola.com", "expires": -1, "si...
# 1883  [{"domain": "c212.net", "expires": 1725408393....
# 1884  [{"domain": ".liadm.com", "expires": 174398491...
# 1885  [{"domain": "t.me", "expires": 1709511599.8026...
# 1886  [{"domain": "wikisource.org", "expires": 17121...
#
#                                            cookie_click  \
# 0     [{"domain": "www.google.com", "expires": 17249...
# 1     [{"domain": ".3lift.com", "expires": 171719202...
# 2     [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3     [{"domain": ".demdex.net", "expires": 17249748...
# 4     [{"domain": ".generac.com", "expires": 1740897...
# ...                                                 ...
# 1882  [{"domain": ".taboola.com", "expires": -1, "si...
# 1883  [{"domain": "c212.net", "expires": 1725408612....
# 1884  [{"domain": ".liadm.com", "expires": 174398491...
# 1885  [{"domain": "t.me", "expires": 1709511599.8026...
# 1886  [{"domain": "wikisource.org", "expires": 17121...
#
#                                         cookie_internal  \
# 0     [{"domain": "www.google.com", "expires": 17249...
# 1     [{"domain": ".3lift.com", "expires": 171719202...
# 2     [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3     [{"domain": ".demdex.net", "expires": 17249748...
# 4     [{"domain": ".generac.com", "expires": 1740897...
# ...                                                 ...
# 1882  [{"domain": ".taboola.com", "expires": -1, "si...
# 1883  [{"domain": "www.ford.com", "expires": 1709511...
# 1884  [{"domain": ".liadm.com", "expires": 174398515...
# 1885  [{"domain": "t.me", "expires": 1709511599.8026...
# 1886  [{"domain": "wikisource.org", "expires": 17121...
#
#                                           domains_first  \
# 0     ["wa.onelink.me", "static.cloudflareinsights.c...
# 1     ["www.skinnytaste.com", "c2shb.ssp.yahoo.com",...
# 2     ["securepubads.g.doubleclick.net", "proc.ad.cp...
# 3     ["unitedstateslibraryofcongress.demdex.net", "...
# 4     ["generac.com", "fonts.googleapis.com", "tags....
# ...                                                 ...
# 1882  ["static.olark.com", "fonts.googleapis.com", "...
# 1883  ["s.go-mpulse.net", "bf12394bze.bf.dynatrace.c...
# 1884  ["p.alocdn.com", "fonts.googleapis.com", "user...
# 1885                                   ["telegram.org"]
# 1886  ["upload.wikimedia.org", "meta.wikimedia.org",...
#
#                                           domains_click us-ohio us-california  \
# 0     ["static.cloudflareinsights.com", "events.char...    True           NaN
# 1     ["www.skinnytaste.com", "c2shb.ssp.yahoo.com",...    True           NaN
# 2     ["crb.kargo.com", "r.3gl.net", "securepubads.g...    True           NaN
# 3     ["smon.loc.gov", "loc.gov", "assets.adobedtm.c...    True           NaN
# 4     ["generac.com", "fonts.googleapis.com", "insig...    True           NaN
# ...                                                 ...     ...           ...
# 1882  ["static.olark.com", "fonts.googleapis.com", "...    True           NaN
# 1883  ["s.go-mpulse.net", "bf12394bze.bf.dynatrace.c...    True           NaN
# 1884  ["acdn.adnxs.com", "api.gotolstoy.com", "insig...    True           NaN
# 1885                                   ["telegram.org"]    True           NaN
# 1886  ["upload.wikimedia.org", "meta.wikimedia.org",...    True           NaN
#
#       ... Science_and_Education Sports Travel_and_Tourism  Vehicles  \
# 0     ...                 False  False              False     False
# 1     ...                 False  False              False     False
# 2     ...                 False  False              False     False
# 3     ...                 False  False              False     False
# 4     ...                 False  False              False     False
# ...   ...                   ...    ...                ...       ...
# 1882  ...                 False  False              False     False
# 1883  ...                 False  False              False      True
# 1884  ...                 False  False              False     False
# 1885  ...                 False  False              False     False
# 1886  ...                 False  False              False     False
#
#       Lifestyle                                     trackers_first  \
# 0         False                        {google.com, appsflyer.com}
# 1         False  {casalemedia.com, bidr.io, flashtalking.com, s...
# 2         False  {casalemedia.com, simpli.fi, creativecdn.com, ...
# 3         False                                       {demdex.net}
# 4         False  {w55c.net, clarity.ms, yahoo.net, adsrvr.org, ...
# ...         ...                                                ...
# 1882      False  {doubleclick.net, bizible.com, twitter.com, bi...
# 1883      False  {amazon-adsystem.com, mathtag.com, simpli.fi, ...
# 1884      False  {casalemedia.com, bidr.io, yahoo.net, tiktok.c...
# 1885      False                                                 {}
# 1886      False                                                 {}
#
#                                          trackers_click  \
# 0                           {google.com, appsflyer.com}
# 1     {casalemedia.com, bidr.io, yahoo.net, flashtal...
# 2     {casalemedia.com, bidr.io, yahoo.net, adsrvr.o...
# 3                                          {demdex.net}
# 4     {w55c.net, casalemedia.com, clarity.ms, yahoo....
# ...                                                 ...
# 1882  {doubleclick.net, bizible.com, twitter.com, bi...
# 1883  {amazon-adsystem.com, mathtag.com, simpli.fi, ...
# 1884  {casalemedia.com, bidr.io, yahoo.net, tiktok.c...
# 1885                                                 {}
# 1886                                                 {}
#
#                                       trackers_internal  \
# 0                           {google.com, appsflyer.com}
# 1     {casalemedia.com, bidr.io, yahoo.net, flashtal...
# 2     {casalemedia.com, bidr.io, yahoo.net, adsrvr.o...
# 3                                          {demdex.net}
# 4     {w55c.net, casalemedia.com, clarity.ms, yahoo....
# ...                                                 ...
# 1882  {doubleclick.net, bizible.com, twitter.com, bi...
# 1883  {casalemedia.com, yahoo.net, simpli.fi, adsrvr...
# 1884  {casalemedia.com, bidr.io, yahoo.net, tiktok.c...
# 1885                                                 {}
# 1886                                                 {}
#
#                                                tp_first  \
# 0     {cloudflareinsights.com, appsflyer.com, google...
# 1     {casalemedia.com, google-analytics.com, flasht...
# 2     {casalemedia.com, google-analytics.com, minute...
# 3                   {demdex.net, loc.gov, adobedtm.com}
# 4     {googleadservices.com, google-analytics.com, a...
# ...                                                 ...
# 1882  {bizibly.com, visualwebsiteoptimizer.com, goog...
# 1883  {googleadservices.com, mpeasylink.com, demdex....
# 1884  {casalemedia.com, bidr.io, google-analytics.co...
# 1885                                     {telegram.org}
# 1886                    {wikimedia.org, wikisource.org}
#
#                                                tp_click
# 0     {cloudflareinsights.com, appsflyer.com, google...
# 1     {casalemedia.com, google-analytics.com, flasht...
# 2     {casalemedia.com, google-analytics.com, adsrvr...
# 3                               {loc.gov, adobedtm.com}
# 4     {casalemedia.com, googleadservices.com, google...
# ...                                                 ...
# 1882  {visualwebsiteoptimizer.com, googletagmanager....
# 1883  {googleadservices.com, mpeasylink.com, demdex....
# 1884  {google-analytics.com, redditstatic.com, adsrv...
# 1885                                     {telegram.org}
# 1886                    {wikimedia.org, wikisource.org}
#
# [1887 rows x 42 columns]
#                           url  \
# 1887      http://character.ai
# 1888   http://skinnytaste.com
# 1889    http://eatingwell.com
# 1890           http://loc.gov
# 1891       http://generac.com
# ...                       ...
# 3757          http://ford.com
# 3758     http://mlsmatrix.com
# 3759  http://litter-robot.com
# 3760              http://t.me
# 3761    http://wikisource.org
#
#                                            landing_page  has_found_banner  \
# 1887                              https://character.ai/             False
# 1888                       https://www.skinnytaste.com/             False
# 1889                        https://www.eatingwell.com/             False
# 1890                                   https://loc.gov/             False
# 1891                               https://generac.com/             False
# ...                                                 ...               ...
# 3757                              https://www.ford.com/             False
# 3758  https://jira-corelogic.valiantys.net/servicede...             False
# 3759                      https://www.litter-robot.com/             False
# 3760                              https://telegram.org/             False
# 3761  https://wikisource.org/wiki/Main_Page/%E0%B7%8...              True
#
#                                            cookie_first  \
# 1887  [{"domain": "www.google.com", "expires": 17256...
# 1888  [{"domain": ".liadm.com", "expires": 174461685...
# 1889  [{"domain": ".capig.dotdashmdp.com", "expires"...
# 1890  [{"domain": ".demdex.net", "expires": 17256198...
# 1891  [{"domain": ".generac.com", "expires": 1741588...
# ...                                                 ...
# 3757  [{"domain": "c212.net", "expires": 1726049805....
# 3758  [{"domain": ".valiantys.net", "expires": 17415...
# 3759  [{"domain": ".liadm.com", "expires": 174462633...
# 3760  [{"domain": "t.me", "expires": 1710153060.2774...
# 3761  [{"domain": "wikisource.org", "expires": 17127...
#
#                                            cookie_click  \
# 1887  [{"domain": "www.google.com", "expires": 17256...
# 1888  [{"domain": ".3lift.com", "expires": 171783298...
# 1889  [{"domain": ".capig.dotdashmdp.com", "expires"...
# 1890  [{"domain": ".demdex.net", "expires": 17256198...
# 1891  [{"domain": ".generac.com", "expires": 1741588...
# ...                                                 ...
# 3757  [{"domain": "c212.net", "expires": 1726050023....
# 3758  [{"domain": ".valiantys.net", "expires": 17415...
# 3759  [{"domain": ".liadm.com", "expires": 174462633...
# 3760  [{"domain": "t.me", "expires": 1710153060.2774...
# 3761  [{"domain": "wikisource.org", "expires": 17127...
#
#                                         cookie_internal  \
# 1887  [{"domain": "www.google.com", "expires": 17256...
# 1888  [{"domain": ".3lift.com", "expires": 171783298...
# 1889  [{"domain": ".capig.dotdashmdp.com", "expires"...
# 1890  [{"domain": "loc.gov", "expires": -1, "size": ...
# 1891  [{"domain": ".generac.com", "expires": 1741588...
# ...                                                 ...
# 3757  [{"domain": "www.ford.com", "expires": 1710152...
# 3758  [{"domain": ".valiantys.net", "expires": 17415...
# 3759  [{"domain": ".liadm.com", "expires": 174462662...
# 3760  [{"domain": "t.me", "expires": 1710153060.2774...
# 3761  [{"domain": "wikisource.org", "expires": 17127...
#
#                                           domains_first  \
# 1887  ["exp.character.ai", "accounts.google.com", "s...
# 1888  ["idx.liadm.com", "ads.adthrive.com", "rtb.ope...
# 1889  ["cdn.p-n.io", "idx.liadm.com", "usermatch.krx...
# 1890  ["assets.adobedtm.com", "dpm.demdex.net", "loc...
# 1891  ["lwjs.azureedge.net", "u.fg8dgt.com", "genera...
# ...                                                 ...
# 3757  ["geolocation.onetrust.com", "www.ford.com", "...
# 3758  ["fonts.googleapis.com", "fonts.gstatic.com", ...
# 3759  ["idx.liadm.com", "usermatch.krxd.net", "sync....
# 3760                                   ["telegram.org"]
# 3761  ["upload.wikimedia.org", "login.wikimedia.org"...
#
#                                           domains_click us-ohio us-california  \
# 1887  ["exp.character.ai", "accounts.google.com", "s...     NaN          True
# 1888  ["de.tynt.com", "idx.liadm.com", "ads.adthrive...     NaN          True
# 1889  ["direct.adsrvr.org", "sli.eatingwell.com", "s...     NaN          True
# 1890  ["assets.adobedtm.com", "smon.loc.gov", "loc.g...     NaN          True
# 1891  ["lwjs.azureedge.net", "u.fg8dgt.com", "genera...     NaN          True
# ...                                                 ...     ...           ...
# 3757  ["geolocation.onetrust.com", "www.ford.com", "...     NaN          True
# 3758  ["fonts.googleapis.com", "fonts.gstatic.com", ...     NaN          True
# 3759  ["s.pinimg.com", "sync.taboola.com", "lm.servi...     NaN          True
# 3760                                   ["telegram.org"]     NaN          True
# 3761  ["upload.wikimedia.org", "meta.wikimedia.org",...     NaN          True
#
#       ... Science_and_Education Sports Travel_and_Tourism  Vehicles  \
# 1887  ...                 False  False              False     False
# 1888  ...                 False  False              False     False
# 1889  ...                 False  False              False     False
# 1890  ...                 False  False              False     False
# 1891  ...                 False  False              False     False
# ...   ...                   ...    ...                ...       ...
# 3757  ...                 False  False              False      True
# 3758  ...                 False  False              False     False
# 3759  ...                 False  False              False     False
# 3760  ...                 False  False              False     False
# 3761  ...                 False  False              False     False
#
#       Lifestyle                                     trackers_first  \
# 1887      False                        {google.com, appsflyer.com}
# 1888      False  {casalemedia.com, bidr.io, yahoo.net, flashtal...
# 1889      False  {casalemedia.com, yahoo.net, simpli.fi, adsrvr...
# 1890      False                                       {demdex.net}
# 1891      False  {w55c.net, clarity.ms, yahoo.net, adsrvr.org, ...
# ...         ...                                                ...
# 3757      False  {amazon-adsystem.com, mathtag.com, simpli.fi, ...
# 3758      False                                                 {}
# 3759      False  {casalemedia.com, bidr.io, yahoo.net, tiktok.c...
# 3760      False                                                 {}
# 3761      False                                                 {}
#
#                                          trackers_click  \
# 1887                        {google.com, appsflyer.com}
# 1888  {casalemedia.com, bidr.io, yahoo.net, flashtal...
# 1889  {casalemedia.com, bidr.io, yahoo.net, adsrvr.o...
# 1890                                       {demdex.net}
# 1891  {w55c.net, casalemedia.com, clarity.ms, yahoo....
# ...                                                 ...
# 3757  {amazon-adsystem.com, mathtag.com, simpli.fi, ...
# 3758                                                 {}
# 3759  {casalemedia.com, bidr.io, yahoo.net, tiktok.c...
# 3760                                                 {}
# 3761                                                 {}
#
#                                       trackers_internal  \
# 1887                        {google.com, appsflyer.com}
# 1888  {bidr.io, adgrx.com, rubiconproject.com, share...
# 1889  {casalemedia.com, bidr.io, yahoo.net, adsrvr.o...
# 1890                                       {demdex.net}
# 1891  {w55c.net, casalemedia.com, clarity.ms, yahoo....
# ...                                                 ...
# 3757  {casalemedia.com, yahoo.net, simpli.fi, adsrvr...
# 3758                                                 {}
# 3759  {casalemedia.com, bidr.io, yahoo.net, tiktok.c...
# 3760                                                 {}
# 3761                                                 {}
#
#                                                tp_first  \
# 1887  {cloudflareinsights.com, appsflyer.com, google...
# 1888  {casalemedia.com, google-analytics.com, acuity...
# 1889  {casalemedia.com, google-analytics.com, minute...
# 1890                {demdex.net, loc.gov, adobedtm.com}
# 1891  {googleadservices.com, google-analytics.com, a...
# ...                                                 ...
# 3757  {googleadservices.com, mpeasylink.com, demdex....
# 3758       {googleapis.com, valiantys.net, gstatic.com}
# 3759  {casalemedia.com, bidr.io, google-analytics.co...
# 3760                                     {telegram.org}
# 3761                    {wikimedia.org, wikisource.org}
#
#                                                tp_click
# 1887  {cloudflareinsights.com, appsflyer.com, google...
# 1888  {casalemedia.com, google-analytics.com, flasht...
# 1889  {casalemedia.com, google-analytics.com, adsrvr...
# 1890                            {loc.gov, adobedtm.com}
# 1891  {casalemedia.com, googleadservices.com, google...
# ...                                                 ...
# 3757  {googleadservices.com, mpeasylink.com, demdex....
# 3758       {googleapis.com, valiantys.net, gstatic.com}
# 3759  {bidr.io, google-analytics.com, redditstatic.c...
# 3760                                     {telegram.org}
# 3761                    {wikimedia.org, wikisource.org}
#
# [1875 rows x 42 columns]
#                           url  \
# 3762      http://character.ai
# 3763   http://skinnytaste.com
# 3764    http://eatingwell.com
# 3765           http://loc.gov
# 3766       http://generac.com
# ...                       ...
# 5632       http://pushpay.com
# 5633     http://mlsmatrix.com
# 5634  http://litter-robot.com
# 5635              http://t.me
# 5636    http://wikisource.org
#
#                                            landing_page  has_found_banner  \
# 3762                              https://character.ai/             False
# 3763                       https://www.skinnytaste.com/             False
# 3764                        https://www.eatingwell.com/             False
# 3765                                   https://loc.gov/             False
# 3766                               https://generac.com/             False
# ...                                                 ...               ...
# 5632                               https://pushpay.com/             False
# 5633                              http://mlsmatrix.com/             False
# 5634                      https://www.litter-robot.com/             False
# 5635                              https://telegram.org/             False
# 5636  https://wikisource.org/wiki/Main_Page/%E0%B7%8...              True
#
#                                            cookie_first  \
# 3762  [{"domain": "www.google.com", "expires": 17256...
# 3763  [{"domain": ".liadm.com", "expires": 174461624...
# 3764  [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3765  [{"domain": ".demdex.net", "expires": 17256180...
# 3766  [{"domain": ".generac.com", "expires": 1741589...
# ...                                                 ...
# 5632  [{"domain": ".taboola.com", "expires": -1, "si...
# 5633                                                 []
# 5634  [{"domain": ".liadm.com", "expires": 174462602...
# 5635  [{"domain": "t.me", "expires": 1710152757.5461...
# 5636  [{"domain": "wikisource.org", "expires": 17127...
#
#                                            cookie_click  \
# 3762  [{"domain": "www.google.com", "expires": 17256...
# 3763  [{"domain": ".liadm.com", "expires": 174461629...
# 3764  [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3765  [{"domain": ".demdex.net", "expires": 17256180...
# 3766  [{"domain": ".generac.com", "expires": 1741589...
# ...                                                 ...
# 5632  [{"domain": ".taboola.com", "expires": -1, "si...
# 5633  [{"domain": ".valiantys.net", "expires": 17415...
# 5634  [{"domain": ".liadm.com", "expires": 174462602...
# 5635  [{"domain": "t.me", "expires": 1710152757.5461...
# 5636  [{"domain": "wikisource.org", "expires": 17127...
#
#                                         cookie_internal  \
# 3762  [{"domain": "www.google.com", "expires": 17256...
# 3763  [{"domain": ".liadm.com", "expires": 174461633...
# 3764  [{"domain": ".capig.dotdashmdp.com", "expires"...
# 3765  [{"domain": ".demdex.net", "expires": 17256180...
# 3766  [{"domain": ".generac.com", "expires": 1741589...
# ...                                                 ...
# 5632  [{"domain": ".taboola.com", "expires": -1, "si...
# 5633  [{"domain": ".valiantys.net", "expires": 17415...
# 5634  [{"domain": ".liadm.com", "expires": 174462632...
# 5635  [{"domain": "t.me", "expires": 1710152757.5461...
# 5636  [{"domain": "wikisource.org", "expires": 17127...
#
#                                           domains_first  \
# 3762  ["content-firebaseappcheck.googleapis.com", "w...
# 3763  ["rtb.gumgum.com", "pixel.tapad.com", "ups.ana...
# 3764  ["pixel.tapad.com", "ats-wrapper.privacymanage...
# 3765  ["loc.gov", "unitedstateslibraryofcongress.dem...
# 3766  ["generac.com", "cdn.pricespider.com", "pixel....
# ...                                                 ...
# 5632  ["d3ltkmc4jesp6t.cloudfront.net", "get.exitint...
# 5633                                  ["mlsmatrix.com"]
# 5634  ["match.360yield.com", "cdn.attn.tv", "ups.ana...
# 5635                                   ["telegram.org"]
# 5636  ["upload.wikimedia.org", "meta.wikimedia.org",...
#
#                                           domains_click us-ohio us-california  \
# 3762  ["content-firebaseappcheck.googleapis.com", "s...     NaN           NaN
# 3763  ["rtb.gumgum.com", "pixel.tapad.com", "ssp.api...     NaN           NaN
# 3764  ["js-sec.indexww.com", "ats-wrapper.privacyman...     NaN           NaN
# 3765  ["loc.gov", "assets.adobedtm.com", "smon.loc.g...     NaN           NaN
# 3766  ["generac.com", "cdn.pricespider.com", "pixel....     NaN           NaN
# ...                                                 ...     ...           ...
# 5632  ["get.exitintel.com", "dev.visualwebsiteoptimi...     NaN           NaN
# 5633  ["fonts.gstatic.com", "fonts.googleapis.com", ...     NaN           NaN
# 5634  ["acdn.adnxs.com", "match.360yield.com", "cdn....     NaN           NaN
# 5635                                   ["telegram.org"]     NaN           NaN
# 5636  ["upload.wikimedia.org", "meta.wikimedia.org",...     NaN           NaN
#
#       ... Science_and_Education Sports Travel_and_Tourism  Vehicles  \
# 3762  ...                 False  False              False     False
# 3763  ...                 False  False              False     False
# 3764  ...                 False  False              False     False
# 3765  ...                 False  False              False     False
# 3766  ...                 False  False              False     False
# ...   ...                   ...    ...                ...       ...
# 5632  ...                 False  False              False     False
# 5633  ...                 False  False              False     False
# 5634  ...                 False  False              False     False
# 5635  ...                 False  False              False     False
# 5636  ...                 False  False              False     False
#
#       Lifestyle                                     trackers_first  \
# 3762      False                        {google.com, appsflyer.com}
# 3763      False  {casalemedia.com, bidr.io, yahoo.net, flashtal...
# 3764      False  {casalemedia.com, bidr.io, yahoo.net, adsrvr.o...
# 3765      False                                       {demdex.net}
# 3766      False  {w55c.net, casalemedia.com, clarity.ms, yahoo....
# ...         ...                                                ...
# 5632      False  {doubleclick.net, bizible.com, twitter.com, bi...
# 5633      False                                                 {}
# 5634      False  {casalemedia.com, bidr.io, yahoo.net, tiktok.c...
# 5635      False                                                 {}
# 5636      False                                                 {}
#
#                                          trackers_click  \
# 3762                        {google.com, appsflyer.com}
# 3763  {casalemedia.com, bidr.io, yahoo.net, flashtal...
# 3764  {casalemedia.com, bidr.io, yahoo.net, adsrvr.o...
# 3765                                       {demdex.net}
# 3766  {w55c.net, casalemedia.com, clarity.ms, yahoo....
# ...                                                 ...
# 5632  {doubleclick.net, bizible.com, twitter.com, bi...
# 5633                                                 {}
# 5634  {casalemedia.com, bidr.io, yahoo.net, tiktok.c...
# 5635                                                 {}
# 5636                                                 {}
#
#                                       trackers_internal  \
# 3762                        {google.com, appsflyer.com}
# 3763  {casalemedia.com, bidr.io, yahoo.net, flashtal...
# 3764  {casalemedia.com, bidr.io, yahoo.net, adsrvr.o...
# 3765                                       {demdex.net}
# 3766  {w55c.net, casalemedia.com, clarity.ms, yahoo....
# ...                                                 ...
# 5632  {doubleclick.net, bizible.com, twitter.com, bi...
# 5633                                                 {}
# 5634  {casalemedia.com, bidr.io, yahoo.net, affirm.c...
# 5635                                                 {}
# 5636                                                 {}
#
#                                                tp_first  \
# 3762  {cloudflareinsights.com, appsflyer.com, google...
# 3763  {casalemedia.com, yahoo.net, flashtalking.com,...
# 3764  {casalemedia.com, yahoo.net, google-analytics....
# 3765                {demdex.net, loc.gov, adobedtm.com}
# 3766  {casalemedia.com, googleadservices.com, google...
# ...                                                 ...
# 5632  {bizibly.com, visualwebsiteoptimizer.com, goog...
# 5633                                    {mlsmatrix.com}
# 5634  {casalemedia.com, bidr.io, yahoo.net, google-a...
# 5635                                     {telegram.org}
# 5636                    {wikimedia.org, wikisource.org}
#
#                                                tp_click
# 3762  {cloudflareinsights.com, appsflyer.com, google...
# 3763  {casalemedia.com, acuityplatform.com, flashtal...
# 3764  {casalemedia.com, google-analytics.com, adsrvr...
# 3765                            {loc.gov, adobedtm.com}
# 3766  {googleadservices.com, google-analytics.com, a...
# ...                                                 ...
# 5632  {visualwebsiteoptimizer.com, googletagmanager....
# 5633       {googleapis.com, valiantys.net, gstatic.com}
# 5634  {google-analytics.com, tiktok.com, redditstati...
# 5635                                     {telegram.org}
# 5636                    {wikimedia.org, wikisource.org}
#
# [1875 rows x 42 columns]
# C:\Users\zhang\AppData\Local\Temp\ipykernel_16124\946328041.py:54: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plot.text(2.5, 115, "Consent Banner Found and Accepted", ha="center", bbox = dict(boxstyle='square,pad=0', facecolor='white', color="white"))

# %%
plot_data = []

for state in state_list:
    this_grouped = df[df[state] == True]
    tot = len(this_grouped.index)
    tot_wo = len(this_grouped[this_grouped["has_found_banner"]==False].index)
    tot_w = len(this_grouped[this_grouped["has_found_banner"]==True].index)
    tracker_first_wo = len(this_grouped[ (this_grouped["trackers_first"].apply(lambda s: len(s) > 0 )) & ( this_grouped["has_found_banner"]==False) ].index)
    tracker_click_wo = len(this_grouped[ (this_grouped["trackers_click"].apply(lambda s: len(s) > 0 )) & ( this_grouped["has_found_banner"]==False) ].index)
    tracker_first_w = len(this_grouped[ (this_grouped["trackers_first"].apply(lambda s: len(s) > 0 )) & ( this_grouped["has_found_banner"]==True) ].index)
    tracker_click_w = len(this_grouped[ (this_grouped["trackers_click"].apply(lambda s: len(s) > 0 )) &( this_grouped["has_found_banner"]==True) ].index)
    plot_data.append({"state": COUNTRY_TRAD[state],
                      BEFORE_STR +  " (w/o Banner)": tracker_click_wo/tot_wo*100, # Use the "Click" visits, to take into account all 
                      BEFORE_STR + " (w/ Banner)": tracker_first_w/tot_w*100,
                      AFTER_STR +  " (w/ Banner)": tracker_click_w/tot_w*100,
                     })
    print(state)
    print(f"BEFORE_STR (w/o Banner): {tracker_click_wo/tot_wo*100}")
    print(f"BEFORE_STR (w/ Banner): {tracker_first_w/tot_w*100}")
    print(f"AFTER_STR (w/ Banner): {tracker_click_w/tot_w*100}")
plot_df = pd.DataFrame(plot_data)
plot_df = plot_df.sort_values(by="state")
plot_df.index = plot_df["state"]
del plot_df["state"]

THIS_PLOT_ARGS = PLOT_ARGS.copy()
THIS_PLOT_ARGS["figsize"] = (4.25,2.25)
    
plot = fastplot.plot( plot_df ,None, 
               mode='bars_multi', ylabel = 'Websites With Trackers [\\%]',
               legend = True, legend_loc='upper left', legend_ncol=2, legend_fontsize="small", legend_alpha = 0.5,
               grid_axis="y",
               ylim = (0,120), **THIS_PLOT_ARGS)


for p in plot.gca().patches[:len(plot_df)] + [plot.gca().get_legend().get_patches()[0]]:
    p.set_hatch(r'|\|\|\|\\')
    p.set_edgecolor ("indianred")
    p.set_facecolor ("white")
for p in plot.gca().patches[len(plot_df):2*len(plot_df)] + [plot.gca().get_legend().get_patches()[1]]:
    p.set_hatch(r'-\-\-\-\\')
    p.set_edgecolor ("darkred")
    p.set_facecolor ("white")

for p in plot.gca().patches[2*len(plot_df):] + [plot.gca().get_legend().get_patches()[2]]:
    p.set_hatch("/////")
    p.set_edgecolor ("blue")
    p.set_facecolor ("white")

plot.subplots_adjust(left=0.125, bottom=0.1, right=0.95, top=0.85) 

# err = plot_df.applymap(lambda v: [ e*100 for e in statsmodels.stats.proportion.proportion_confint(v*2500/100,2500,0.05) ]  )
err = plot_df.map(lambda v: [ e*100 for e in statsmodels.stats.proportion.proportion_confint(v*2500/100,2500,0.05) ]  )
for i, tup in enumerate(err.itertuples()):
    plot.gca().plot( (i-0.2,i-0.2), (tup[1]), linestyle="-", color="black"  )
    plot.gca().plot( (i,i), (tup[2]), linestyle="-", color="black" )
    plot.gca().plot( (i+0.2,i+0.2), (tup[3]), linestyle="-", color="black" )

plot.savefig("plots/cookieaccept_websites_with_trackers_separate.pdf", bbox_inches = "tight")
plot.show()
# Out:
# us-ohio
# BEFORE_STR (w/o Banner): 62.33354470513633
# BEFORE_STR (w/ Banner): 74.83870967741936
# AFTER_STR (w/ Banner): 85.80645161290322
# us-california
# BEFORE_STR (w/o Banner): 62.10526315789474
# BEFORE_STR (w/ Banner): 74.08450704225352
# AFTER_STR (w/ Banner): 87.32394366197182
# us-virginia
# BEFORE_STR (w/o Banner): 62.44343891402715
# BEFORE_STR (w/ Banner): 75.60975609756098
# AFTER_STR (w/ Banner): 86.89024390243902

# %%
plot_data = []
plot_data_error = []
for state in state_list:
    this_grouped = df[df[state] == True]
    tracker_first = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_first"].apply(len).mean()
    tracker_click = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_click"].apply(len).mean()
    tracker_internal = this_grouped[this_grouped["trackers_internal"].apply(lambda s: len(s) >= 0 ) ]["trackers_internal"].apply(len).mean()
    
    plot_data.append({"state": COUNTRY_TRAD[state],
                      BEFORE_STR: tracker_first,
                      AFTER_STR: tracker_click,
                      ADDITIONAL_STR: tracker_internal,
                     })
    
    tracker_first = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_first"].apply(len)
    tracker_click = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_click"].apply(len)
    tracker_internal = this_grouped[this_grouped["trackers_internal"].apply(lambda s: len(s) >= 0 ) ]["trackers_internal"].apply(len)
      
    plot_data_error.append({"country": COUNTRY_TRAD[state],
                      BEFORE_STR: (round(np.mean(tracker_first) - 1.95*np.std(tracker_first)/np.sqrt(len(tracker_first)),2),
                                   round(np.mean(tracker_first) + 1.95*np.std(tracker_first)/np.sqrt(len(tracker_first)),2)),
                      AFTER_STR: (round(np.mean(tracker_click) - 1.95*np.std(tracker_click)/np.sqrt(len(tracker_click)),2),
                                   round(np.mean(tracker_click) + 1.95*np.std(tracker_click)/np.sqrt(len(tracker_click)),2)),
                      ADDITIONAL_STR: (round(np.mean(tracker_internal) - 1.95*np.std(tracker_click)/np.sqrt(len(tracker_internal)),2),
                                   round(np.mean(tracker_internal) + 1.95*np.std(tracker_click)/np.sqrt(len(tracker_internal)),2)),
                     })
    
plot_df = pd.DataFrame(plot_data)
plot_df = plot_df.sort_values(by="state")
plot_df.index = plot_df["state"]
del plot_df["state"]

THIS_PLOT_ARGS = PLOT_ARGS.copy()
THIS_PLOT_ARGS["figsize"] = (4.25,2.25)


plot = fastplot.plot( plot_df [[BEFORE_STR, AFTER_STR, ADDITIONAL_STR] ]  ,None, 
               mode='bars_multi', ylabel = 'Average Trackers Per Website',
               legend = True, legend_loc='upper left', legend_ncol=3, legend_fontsize=9,
               grid_axis="y", yticks=(np.arange(0,21,2) ,None),
               ylim = (0,21), **THIS_PLOT_ARGS)

for p in plot.gca().patches[:len(plot_df)] + [plot.gca().get_legend().get_patches()[0]]:
    p.set_hatch("\\\\\\\\\\")
    p.set_edgecolor ("red")
    p.set_facecolor ("white")
for p in plot.gca().patches[len(plot_df):2*len(plot_df)] + [plot.gca().get_legend().get_patches()[1]]:
    p.set_hatch("/////")
    p.set_edgecolor ("blue")
    p.set_facecolor ("white")

for p in plot.gca().patches[2*len(plot_df):] + [plot.gca().get_legend().get_patches()[2]]:
    p.set_hatch("----")
    p.set_edgecolor ("green")
    p.set_facecolor ("white")
    
#plot.gca().patches[5].set_hatch("XXXX")
#plot.gca().patches[11].set_hatch("++++")
#plot.gca().patches[17].set_hatch("....")

for i, tup in enumerate(plot_df.itertuples()):
    #print(i, tup.Index)
    this_d = None
    for d in plot_data_error:
        if d["country"] == tup.Index:
            this_d = d
    #print (tup.Index, this_d)
    plot.gca().plot( (i-0.2,i-0.2), (this_d[BEFORE_STR]), linestyle="-", color="black"  )
    plot.gca().plot( (i,i), (this_d[AFTER_STR]), linestyle="-", color="black" )
    plot.gca().plot( (i+0.2,i+0.2), (this_d[ADDITIONAL_STR]), linestyle="-", color="black" )
    print(tup)
    print(f"BEFORE_STR: {this_d[BEFORE_STR]}")
    print(f"AFTER_STR: {this_d[AFTER_STR]}")
    print(f"ADDITIONAL_STR: {this_d[ADDITIONAL_STR]}")
    
plot.savefig("plots/cookieaccept_trackers_per_website.pdf")
plot.show()
# Out:
#   Cell In[23], line 28
#     print(f"BEFORE_STR: {(round(np.mean(tracker_first) - 1.95*np.std(tracker_first)/np.sqrt(len(tracker_first)),2),
#           ^
# SyntaxError: unterminated string literal (detected at line 28)

# %%
plot_data = []
plot_data_error = []

for country in similarweb_websites.keys():
    this_grouped = grouped[grouped[country] == True]
    tracker_first_wo = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==False)]["trackers_first"].apply(len).mean()
    tracker_click_wo = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==False)]["trackers_click"].apply(len).mean()
    tracker_first_w = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==True)]["trackers_first"].apply(len).mean()
    tracker_click_w = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==True)]["trackers_click"].apply(len).mean()
     
    plot_data.append({"country": COUNTRY_TRAD[country],
                      BEFORE_STR +  " (w/o Banner)": tracker_click_wo, # Use the "Click" visits, to take into account all 
                      BEFORE_STR + " (w/ Banner)": tracker_first_w,
                      AFTER_STR +  " (w/ Banner)": tracker_click_w,
                     })

    tracker_first_wo = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==False)]["trackers_first"].apply(len)
    tracker_click_wo = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==False)]["trackers_click"].apply(len)
    tracker_first_w = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==True)]["trackers_first"].apply(len)
    tracker_click_w = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==True)]["trackers_click"].apply(len)
     
    plot_data_error.append({"country": COUNTRY_TRAD[country],
                      BEFORE_STR +  " (w/o Banner)": (round(np.mean(tracker_click_wo) - 1.95*np.std(tracker_click_wo)/np.sqrt(len(tracker_click_wo)),2),
                                   round(np.mean(tracker_click_wo) + 1.95*np.std(tracker_click_wo)/np.sqrt(len(tracker_click_wo)),2)),
                      BEFORE_STR + " (w/ Banner)": (round(np.mean(tracker_first_w) - 1.95*np.std(tracker_click)/np.sqrt(len(tracker_first_w)),2),
                                   round(np.mean(tracker_first_w) + 1.95*np.std(tracker_first_w)/np.sqrt(len(tracker_first_w)),2)),
                      AFTER_STR +  " (w/ Banner)": (round(np.mean(tracker_click_w) - 1.95*np.std(tracker_click_w)/np.sqrt(len(tracker_click_w)),2),
                                   round(np.mean(tracker_click_w) + 1.95*np.std(tracker_click_w)/np.sqrt(len(tracker_click_w)),2)),
                     })
    
plot_df = pd.DataFrame(plot_data)
plot_df = plot_df.sort_values(by="country")
plot_df.index = plot_df["country"]
del plot_df["country"]

THIS_PLOT_ARGS = PLOT_ARGS.copy()
THIS_PLOT_ARGS["figsize"] = (4.25,2.25)

plot = fastplot.plot(plot_df[[BEFORE_STR + " (w/o Banner)", BEFORE_STR + " (w/ Banner)", AFTER_STR + " (w/ Banner)"]],
                     None, 
                     mode='bars_multi', 
                     ylabel='Average Trackers Per Website',
                     legend=True, 
                     legend_loc='upper left', 
                     legend_ncol=2, 
                     legend_fontsize=8.75, 
                     legend_alpha=1,
                     grid_axis="y", 
                     yticks=(np.arange(0, 21, 2), None),
                     ylim=(0, 21), 
                     **THIS_PLOT_ARGS)

# Modify here to adjust the legend position
plot.gca().legend(loc='upper left', bbox_to_anchor=(1, 1))

for p in plot.gca().patches[:len(plot_df)] + [plot.gca().get_legend().get_patches()[0]]:
    p.set_hatch(r'|\|\|\|\\')
    p.set_edgecolor ("indianred")
    p.set_facecolor ("white")
for p in plot.gca().patches[len(plot_df):2*len(plot_df)] + [plot.gca().get_legend().get_patches()[1]]:
    p.set_hatch(r'-\-\-\-\\')
    p.set_edgecolor ("darkred")
    p.set_facecolor ("white")

for p in plot.gca().patches[2*len(plot_df):] + [plot.gca().get_legend().get_patches()[2]]:
    p.set_hatch("/////")
    p.set_edgecolor ("blue")
    p.set_facecolor ("white")
    

for i, tup in enumerate(plot_df.itertuples()):
    #print(i, tup.Index)
    this_d = None
    for d in plot_data_error:
        if d["country"] == tup.Index:
            this_d = d
    #print (tup.Index, this_d)
    plot.gca().plot( (i-0.2,i-0.2), (this_d[BEFORE_STR +  " (w/o Banner)"]), linestyle="-", color="black"  )
    plot.gca().plot( (i,i), (this_d[BEFORE_STR +  " (w/ Banner)"]), linestyle="-", color="black" )
    plot.gca().plot( (i+0.2,i+0.2), (this_d[AFTER_STR +  " (w/ Banner)"]), linestyle="-", color="black" )
    
# plot.savefig("../plots/cookieaccept_trackers_per_website_separate.pdf")
plot.savefig("plots/cookieaccept_trackers_per_website_separate.pdf")
plot.show()

# %%
tracker_first = Counter()
tracker_click = Counter()
tot = len(this_grouped.index)

for row in this_grouped.itertuples():
    for t in row.trackers_first:
        tracker_first[t] +=1
    for t in row.trackers_click:
        tracker_click[t] +=1        

plot_data = []
for t in tracker_first:
    plot_data.append({
        "tracker": t,
        BEFORE_STR: tracker_first[t]/tot*100,
        AFTER_STR: tracker_click[t]/tot*100,
    })
    
plot_df = pd.DataFrame(plot_data)
plot_df = plot_df.sort_values(by = BEFORE_STR, ascending=False)


plot_list = [(BEFORE_STR,   (np.arange(len(plot_df[BEFORE_STR].values ) ) +1 ,   plot_df[BEFORE_STR].values  ) ),
             (AFTER_STR, (np.arange(len(plot_df[AFTER_STR].values) ) +1 , plot_df[AFTER_STR].values ) ),
            ]

plot = fastplot.plot( plot_list ,None, 
               mode='line_multi', ylabel = 'Pervasiveness [\\%]',
               legend = True, legend_loc='lower left', legend_ncol=1,
               yscale = "log", xscale = "log", xlabel = "Tracker Rank",
               xlim = (0.85, None), cycler = CYCLER_LINESPOINTS, plot_args = {"markersize": 4, "markevery": slice(0, 10, 1)},
               ylim = (0.01,100), **PLOT_ARGS)

plot.savefig("plots/cookieaccept_tracker_pervasiveness_log.pdf")
plot.show()

print("Trackers on >= 1% of websites: {} -> {}".format( len([e for e in plot_list[0][1][1] if e > 1 ]), len([e for e in plot_list[1][1][1] if e >1 ]) ))
# Out:
# Trackers on >= 1% of websites: 57 -> 99

# %%
plot_data = []

for category in categories.keys():
    this_grouped = grouped[grouped[category] == True]
    this_grouped = this_grouped [ this_grouped[country_list].any(axis=1) ] 
    tot = len(this_grouped.index)
    tracker_first = len(this_grouped[this_grouped["trackers_first"].apply(lambda s: len(s) > 0 ) ].index)
    tracker_click = len(this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) > 0 ) ].index)
    tracker_internal = len(this_grouped[this_grouped["trackers_internal"].apply(lambda s: len(s) > 0 ) ].index)
    if tot>0:
        plot_data.append({"category": category,
                          BEFORE_STR: tracker_first/tot*100,
                          AFTER_STR: tracker_click/tot*100,
                          ADDITIONAL_STR: tracker_internal/tot*100,
                         })
    else:
        print ("    Empty")
    
plot_df = pd.DataFrame(plot_data)
plot_df.index = plot_df["category"]

plot_df = plot_df.sort_values(by = BEFORE_STR, ascending=False)
del plot_df["category"]
THIS_PLOT_ARGS_LARGE = {"style":"latex", "grid":True, "figsize":(9,2), "rcParams":{'text.latex.preamble': '\\usepackage{libertine}\n\\usepackage{setspace}'}, "legend_args":{"columnspacing":1, "handlelength":1.5}}

plot = fastplot.plot( plot_df[[BEFORE_STR, AFTER_STR, ADDITIONAL_STR] ] ,None, 
               mode='bars_multi', ylabel = 'Websites\\\\With Trackers [\\%]', xticks_rotate = 30, xticks_fontsize = "small",
               legend = True, legend_loc='upper right', legend_ncol=3, legend_alpha=1.0,
               grid_axis="y", yticks = ([0,25,50,75,100], None),
               ylim = (0,110), **THIS_PLOT_ARGS_LARGE)

for p in plot.gca().patches[:len(plot_df)] + [plot.gca().get_legend().get_patches()[0]]:
    p.set_hatch("\\\\\\\\\\")
    p.set_edgecolor ("red")
    p.set_facecolor ("white")
for p in plot.gca().patches[len(plot_df):2*len(plot_df)]+ [plot.gca().get_legend().get_patches()[1]]:
    p.set_hatch("/////")
    p.set_edgecolor ("blue")
    p.set_facecolor ("white")
    
for p in plot.gca().patches[2*len(plot_df):] + [plot.gca().get_legend().get_patches()[2]]:
    p.set_hatch("----")
    p.set_edgecolor ("green")
    p.set_facecolor ("white")

for i, category in enumerate(plot_df.index.values):
    this_grouped = grouped[grouped[category] == True]
    n = int(len(this_grouped[this_grouped["has_found_banner"]].index)/len(this_grouped.index)*100)
    plot.text(i, 114, "\\small {}\\%".format(n), ha="center", bbox = dict(boxstyle='square,pad=0', color="white"))
    
plot.text(11, 122, "Consent Banner Found and Accepted", ha="center", bbox = dict(boxstyle='square,pad=0', facecolor='white', color="white"))

plot.subplots_adjust(left=0.125, bottom=0.1, right=0.95, top=0.85) 


# err = plot_df.applymap(lambda v: [ e*100 for e in statsmodels.stats.proportion.proportion_confint(v*500/100,500,0.05) ]  )
err = plot_df.map(lambda v: [ e*100 for e in statsmodels.stats.proportion.proportion_confint(v*500/100,500,0.05) ]  )
for i, tup in enumerate(err.itertuples()):
    plot.gca().plot( (i-0.2,i-0.2), (tup[1]), linestyle="-", color="black"  )
    plot.gca().plot( (i,i), (tup[2]), linestyle="-", color="black" )
    plot.gca().plot( (i+0.2,i+0.2), (tup[3]), linestyle="-", color="black" )
    
plot.savefig("plots/cookieaccept_websites_with_trackers_category.pdf", bbox_inches = "tight")
plot.show()
# Out:
# C:\Users\zhang\AppData\Local\Temp\ipykernel_19028\1810028308.py:51: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plot.text(11, 122, "Consent Banner Found and Accepted", ha="center", bbox = dict(boxstyle='square,pad=0', facecolor='white', color="white"))

# %%
plot_data = []
plot_data_error = []

for category in categories.keys():
    this_grouped = grouped[grouped[category] == True]
    this_grouped = this_grouped [ this_grouped[country_list].any(axis=1) ] 
    tracker_first = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_first"].apply(len).mean()
    tracker_click = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_click"].apply(len).mean()
    tracker_internal = this_grouped[this_grouped["trackers_internal"].apply(lambda s: len(s) >= 0 ) ]["trackers_internal"].apply(len).mean()
    
    plot_data.append({"category": category,
                     BEFORE_STR: tracker_first,
                      AFTER_STR: tracker_click,
                      ADDITIONAL_STR: tracker_internal,
                     })
    
    tracker_first = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_first"].apply(len)
    tracker_click = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_click"].apply(len)
    tracker_internal = this_grouped[this_grouped["trackers_internal"].apply(lambda s: len(s) >= 0 ) ]["trackers_internal"].apply(len)
      
    plot_data_error.append({"category": category,
                      BEFORE_STR: (round(np.mean(tracker_first) - 1.95*np.std(tracker_first)/np.sqrt(len(tracker_first)),2),
                                   round(np.mean(tracker_first) + 1.95*np.std(tracker_first)/np.sqrt(len(tracker_first)),2)),
                      AFTER_STR: (round(np.mean(tracker_click) - 1.95*np.std(tracker_click)/np.sqrt(len(tracker_click)),2),
                                   round(np.mean(tracker_click) + 1.95*np.std(tracker_click)/np.sqrt(len(tracker_click)),2)),
                      ADDITIONAL_STR: (round(np.mean(tracker_internal) - 1.95*np.std(tracker_click)/np.sqrt(len(tracker_internal)),2),
                                   round(np.mean(tracker_internal) + 1.95*np.std(tracker_click)/np.sqrt(len(tracker_internal)),2)),
                     })
    
plot_df = pd.DataFrame(plot_data)
plot_df.index = plot_df["category"]
plot_df = plot_df.sort_values(by = BEFORE_STR, ascending=False)

del plot_df["category"]
plot = fastplot.plot( plot_df[[BEFORE_STR, AFTER_STR, ADDITIONAL_STR] ] ,None, 
               mode='bars_multi', ylabel = '\\begin{center}Average Trackers\\\\Per Website\\end{center}', xticks_rotate = 30,  xticks_fontsize = "small",
               legend = True, legend_loc='upper right', legend_ncol=3,
               grid_axis="y",yticks = (np.arange(0,55,5), None),
               ylim = (0,50), **PLOT_ARGS_LARGE)

for p in plot.gca().patches[:len(plot_df)] + [plot.gca().get_legend().get_patches()[0]]:
    p.set_hatch("\\\\\\\\\\")
    p.set_edgecolor ("red")
    p.set_facecolor ("white")
for p in plot.gca().patches[len(plot_df):2*len(plot_df)] + [plot.gca().get_legend().get_patches()[1]]:
    p.set_hatch("/////")
    p.set_edgecolor ("blue")
    p.set_facecolor ("white")

for p in plot.gca().patches[2*len(plot_df):] + [plot.gca().get_legend().get_patches()[2]]:
    p.set_hatch("----")
    p.set_edgecolor ("green")
    p.set_facecolor ("white")
    

for i, tup in enumerate(plot_df.itertuples()):
    for d in plot_data_error:
        if d["category"] == tup.Index:
            this_d = d
    plot.gca().plot( (i-0.2,i-0.2), (this_d[BEFORE_STR]), linestyle="-", color="black"  )
    plot.gca().plot( (i,i), (this_d[AFTER_STR]), linestyle="-", color="black" )
    plot.gca().plot( (i+0.2,i+0.2), (this_d[ADDITIONAL_STR]), linestyle="-", color="black" )
plot.savefig("plots/cookieaccept_trackers_per_website_category.pdf")
plot.show()
plot_df["Increase"] = plot_df[AFTER_STR] - plot_df[BEFORE_STR]
